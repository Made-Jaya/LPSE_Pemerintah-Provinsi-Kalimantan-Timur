# %%
from selenium import webdriver
import pandas as pd
import time
import os  
from tqdm import tqdm
from selenium.webdriver.common.by import By

# %%
chromedriver_location = "C:/Users/madej/Downloads/chromedriver_win32/chromedriver.exe"

# %%
driver = webdriver.Chrome(chromedriver_location)
# Out:
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\2255847859.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(chromedriver_location)

# %%
driver.get('https://lpse.kaltimprov.go.id/eproc4/lelang')

# %%
halamanutama_all = pd.DataFrame()

# %%
driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
banyakhalaman = driver.find_element(By.XPATH, '//*[@id="tbllelang_paginate"]/ul/li[9]/a').text

# %%
def loaddata(i):
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    driver.switch_to.window(driver.window_handles[0])
    link = '//*[@id="tbllelang"]/tbody/tr[{}]/td[2]/p[1]/a'.format(i)
    driver.find_element_by_xpath(str(link)).click()
    driver.switch_to.window(driver.window_handles[1])
    Calon_Pengumuman = pd.DataFrame(pd.read_html(driver.page_source)[0])
    driver.find_element_by_xpath(str('//*[@id="main"]/ul/li[2]/a')).click()
    Peserta = pd.DataFrame(pd.read_html(driver.page_source)[0])
    driver.close()
    driver.switch_to.window(driver.window_handles[0])
        
    Pengumuman = pd.DataFrame()
    Pengumuman['Deskripsi'] = Calon_Pengumuman[Calon_Pengumuman.columns[1]]
    Pengumuman.index = Calon_Pengumuman[Calon_Pengumuman.columns[0]]
    
    if len(Peserta.columns) > 2 :
        Peserta['Harga Penawaran'] = Peserta['Harga Penawaran'].str.replace('Rp. ', '')
        Peserta['Harga Penawaran'] = Peserta['Harga Penawaran'].str.replace('.', '')
        Peserta['Harga Penawaran'] = Peserta['Harga Penawaran'].str.replace(',', '.')
        Peserta['Harga Terkoreksi'] = Peserta['Harga Terkoreksi'].str.replace('Rp. ', '')
        Peserta['Harga Terkoreksi'] = Peserta['Harga Terkoreksi'].str.replace('.', '')
        Peserta['Harga Terkoreksi'] = Peserta['Harga Terkoreksi'].str.replace(',', '.')
    
    # Create a Pandas Excel writer using XlsxWriter as the engine.
    writer = pd.ExcelWriter("LPSE_POV_KALTIM/"+str(Pengumuman[Pengumuman.columns[0]][0])+'.xlsx', engine='xlsxwriter')
    Pengumuman.to_excel(writer, sheet_name='Pengumuman')
    Peserta.to_excel(writer, sheet_name='Peserta')
    writer.save()

# %%
for i in tqdm(range(2,int(banyakhalaman))):
    time.sleep(5)
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    halamanutama = pd.DataFrame(pd.read_html(driver.page_source)[1])
    halamanutama_all = halamanutama_all.append(halamanutama, ignore_index=True)
    driver.find_element_by_xpath(str('//*[@id="tbllelang_next"]/a')).click()
    for ii in range(1,len(pd.read_html(driver.page_source)[1])):
        try:
            loaddata(ii)
        except:
            print("Erorr"+str(ii))
# Out:
#   0%|          | 0/436 [00:00<?, ?it/s]C:\Users\madej\AppData\Local\Temp\ipykernel_9056\2318968024.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   halamanutama_all = halamanutama_all.append(halamanutama, ignore_index=True)
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\2318968024.py:6: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str('//*[@id="tbllelang_next"]/a')).click()
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:5: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str(link)).click()
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str('//*[@id="main"]/ul/li[2]/a')).click()
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:5: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str(link)).click()
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str('//*[@id="main"]/ul/li[2]/a')).click()
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
#   Peserta['Harga Penawaran'] = Peserta['Harga Penawaran'].str.replace('Rp. ', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:19: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Peserta['Harga Penawaran'] = Peserta['Harga Penawaran'].str.replace('.', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:21: FutureWarning: The default value of regex will change from True to False in a future version.
#   Peserta['Harga Terkoreksi'] = Peserta['Harga Terkoreksi'].str.replace('Rp. ', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Peserta['Harga Terkoreksi'] = Peserta['Harga Terkoreksi'].str.replace('.', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:5: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str(link)).click()
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str('//*[@id="main"]/ul/li[2]/a')).click()
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
#   Peserta['Harga Penawaran'] = Peserta['Harga Penawaran'].str.replace('Rp. ', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:19: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Peserta['Harga Penawaran'] = Peserta['Harga Penawaran'].str.replace('.', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:21: FutureWarning: The default value of regex will change from True to False in a future version.
#   Peserta['Harga Terkoreksi'] = Peserta['Harga Terkoreksi'].str.replace('Rp. ', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Peserta['Harga Terkoreksi'] = Peserta['Harga Terkoreksi'].str.replace('.', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:5: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str(link)).click()
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str('//*[@id="main"]/ul/li[2]/a')).click()
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
#   Peserta['Harga Penawaran'] = Peserta['Harga Penawaran'].str.replace('Rp. ', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:19: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Peserta['Harga Penawaran'] = Peserta['Harga Penawaran'].str.replace('.', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:21: FutureWarning: The default value of regex will change from True to False in a future version.
#   Peserta['Harga Terkoreksi'] = Peserta['Harga Terkoreksi'].str.replace('Rp. ', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Peserta['Harga Terkoreksi'] = Peserta['Harga Terkoreksi'].str.replace('.', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:5: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str(link)).click()
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str('//*[@id="main"]/ul/li[2]/a')).click()
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
#   Peserta['Harga Penawaran'] = Peserta['Harga Penawaran'].str.replace('Rp. ', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:19: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Peserta['Harga Penawaran'] = Peserta['Harga Penawaran'].str.replace('.', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:21: FutureWarning: The default value of regex will change from True to False in a future version.
#   Peserta['Harga Terkoreksi'] = Peserta['Harga Terkoreksi'].str.replace('Rp. ', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Peserta['Harga Terkoreksi'] = Peserta['Harga Terkoreksi'].str.replace('.', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:5: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str(link)).click()
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str('//*[@id="main"]/ul/li[2]/a')).click()
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
#   Peserta['Harga Penawaran'] = Peserta['Harga Penawaran'].str.replace('Rp. ', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:19: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Peserta['Harga Penawaran'] = Peserta['Harga Penawaran'].str.replace('.', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:21: FutureWarning: The default value of regex will change from True to False in a future version.
#   Peserta['Harga Terkoreksi'] = Peserta['Harga Terkoreksi'].str.replace('Rp. ', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Peserta['Harga Terkoreksi'] = Peserta['Harga Terkoreksi'].str.replace('.', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:5: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str(link)).click()
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str('//*[@id="main"]/ul/li[2]/a')).click()
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
#   Peserta['Harga Penawaran'] = Peserta['Harga Penawaran'].str.replace('Rp. ', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:19: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Peserta['Harga Penawaran'] = Peserta['Harga Penawaran'].str.replace('.', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:21: FutureWarning: The default value of regex will change from True to False in a future version.
#   Peserta['Harga Terkoreksi'] = Peserta['Harga Terkoreksi'].str.replace('Rp. ', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Peserta['Harga Terkoreksi'] = Peserta['Harga Terkoreksi'].str.replace('.', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:5: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str(link)).click()
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str('//*[@id="main"]/ul/li[2]/a')).click()
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
#   Peserta['Harga Penawaran'] = Peserta['Harga Penawaran'].str.replace('Rp. ', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:19: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Peserta['Harga Penawaran'] = Peserta['Harga Penawaran'].str.replace('.', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:21: FutureWarning: The default value of regex will change from True to False in a future version.
#   Peserta['Harga Terkoreksi'] = Peserta['Harga Terkoreksi'].str.replace('Rp. ', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Peserta['Harga Terkoreksi'] = Peserta['Harga Terkoreksi'].str.replace('.', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:5: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str(link)).click()
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str('//*[@id="main"]/ul/li[2]/a')).click()
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
#   Peserta['Harga Penawaran'] = Peserta['Harga Penawaran'].str.replace('Rp. ', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:19: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Peserta['Harga Penawaran'] = Peserta['Harga Penawaran'].str.replace('.', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:21: FutureWarning: The default value of regex will change from True to False in a future version.
#   Peserta['Harga Terkoreksi'] = Peserta['Harga Terkoreksi'].str.replace('Rp. ', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Peserta['Harga Terkoreksi'] = Peserta['Harga Terkoreksi'].str.replace('.', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:5: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str(link)).click()
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str('//*[@id="main"]/ul/li[2]/a')).click()
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
#   Peserta['Harga Penawaran'] = Peserta['Harga Penawaran'].str.replace('Rp. ', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:19: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Peserta['Harga Penawaran'] = Peserta['Harga Penawaran'].str.replace('.', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:21: FutureWarning: The default value of regex will change from True to False in a future version.
#   Peserta['Harga Terkoreksi'] = Peserta['Harga Terkoreksi'].str.replace('Rp. ', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Peserta['Harga Terkoreksi'] = Peserta['Harga Terkoreksi'].str.replace('.', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:5: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str(link)).click()
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str('//*[@id="main"]/ul/li[2]/a')).click()
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
#   Peserta['Harga Penawaran'] = Peserta['Harga Penawaran'].str.replace('Rp. ', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:19: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Peserta['Harga Penawaran'] = Peserta['Harga Penawaran'].str.replace('.', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:21: FutureWarning: The default value of regex will change from True to False in a future version.
#   Peserta['Harga Terkoreksi'] = Peserta['Harga Terkoreksi'].str.replace('Rp. ', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Peserta['Harga Terkoreksi'] = Peserta['Harga Terkoreksi'].str.replace('.', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:5: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str(link)).click()
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str('//*[@id="main"]/ul/li[2]/a')).click()
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
#   Peserta['Harga Penawaran'] = Peserta['Harga Penawaran'].str.replace('Rp. ', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:19: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Peserta['Harga Penawaran'] = Peserta['Harga Penawaran'].str.replace('.', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:21: FutureWarning: The default value of regex will change from True to False in a future version.
#   Peserta['Harga Terkoreksi'] = Peserta['Harga Terkoreksi'].str.replace('Rp. ', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Peserta['Harga Terkoreksi'] = Peserta['Harga Terkoreksi'].str.replace('.', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:5: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str(link)).click()
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str('//*[@id="main"]/ul/li[2]/a')).click()
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
#   Peserta['Harga Penawaran'] = Peserta['Harga Penawaran'].str.replace('Rp. ', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:19: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Peserta['Harga Penawaran'] = Peserta['Harga Penawaran'].str.replace('.', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:21: FutureWarning: The default value of regex will change from True to False in a future version.
#   Peserta['Harga Terkoreksi'] = Peserta['Harga Terkoreksi'].str.replace('Rp. ', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Peserta['Harga Terkoreksi'] = Peserta['Harga Terkoreksi'].str.replace('.', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:5: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str(link)).click()
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str('//*[@id="main"]/ul/li[2]/a')).click()
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
#   Peserta['Harga Penawaran'] = Peserta['Harga Penawaran'].str.replace('Rp. ', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:19: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Peserta['Harga Penawaran'] = Peserta['Harga Penawaran'].str.replace('.', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:21: FutureWarning: The default value of regex will change from True to False in a future version.
#   Peserta['Harga Terkoreksi'] = Peserta['Harga Terkoreksi'].str.replace('Rp. ', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Peserta['Harga Terkoreksi'] = Peserta['Harga Terkoreksi'].str.replace('.', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:5: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str(link)).click()
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str('//*[@id="main"]/ul/li[2]/a')).click()
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
#   Peserta['Harga Penawaran'] = Peserta['Harga Penawaran'].str.replace('Rp. ', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:19: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Peserta['Harga Penawaran'] = Peserta['Harga Penawaran'].str.replace('.', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:21: FutureWarning: The default value of regex will change from True to False in a future version.
#   Peserta['Harga Terkoreksi'] = Peserta['Harga Terkoreksi'].str.replace('Rp. ', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Peserta['Harga Terkoreksi'] = Peserta['Harga Terkoreksi'].str.replace('.', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:5: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str(link)).click()
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str('//*[@id="main"]/ul/li[2]/a')).click()
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
#   Peserta['Harga Penawaran'] = Peserta['Harga Penawaran'].str.replace('Rp. ', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:19: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Peserta['Harga Penawaran'] = Peserta['Harga Penawaran'].str.replace('.', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:21: FutureWarning: The default value of regex will change from True to False in a future version.
#   Peserta['Harga Terkoreksi'] = Peserta['Harga Terkoreksi'].str.replace('Rp. ', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Peserta['Harga Terkoreksi'] = Peserta['Harga Terkoreksi'].str.replace('.', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:5: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str(link)).click()
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str('//*[@id="main"]/ul/li[2]/a')).click()
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
#   Peserta['Harga Penawaran'] = Peserta['Harga Penawaran'].str.replace('Rp. ', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:19: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Peserta['Harga Penawaran'] = Peserta['Harga Penawaran'].str.replace('.', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:21: FutureWarning: The default value of regex will change from True to False in a future version.
#   Peserta['Harga Terkoreksi'] = Peserta['Harga Terkoreksi'].str.replace('Rp. ', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Peserta['Harga Terkoreksi'] = Peserta['Harga Terkoreksi'].str.replace('.', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:5: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str(link)).click()
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str('//*[@id="main"]/ul/li[2]/a')).click()
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
#   Peserta['Harga Penawaran'] = Peserta['Harga Penawaran'].str.replace('Rp. ', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:19: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Peserta['Harga Penawaran'] = Peserta['Harga Penawaran'].str.replace('.', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:21: FutureWarning: The default value of regex will change from True to False in a future version.
#   Peserta['Harga Terkoreksi'] = Peserta['Harga Terkoreksi'].str.replace('Rp. ', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Peserta['Harga Terkoreksi'] = Peserta['Harga Terkoreksi'].str.replace('.', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:5: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str(link)).click()
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str('//*[@id="main"]/ul/li[2]/a')).click()
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
#   Peserta['Harga Penawaran'] = Peserta['Harga Penawaran'].str.replace('Rp. ', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:19: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Peserta['Harga Penawaran'] = Peserta['Harga Penawaran'].str.replace('.', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:21: FutureWarning: The default value of regex will change from True to False in a future version.
#   Peserta['Harga Terkoreksi'] = Peserta['Harga Terkoreksi'].str.replace('Rp. ', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Peserta['Harga Terkoreksi'] = Peserta['Harga Terkoreksi'].str.replace('.', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:5: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str(link)).click()
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str('//*[@id="main"]/ul/li[2]/a')).click()
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
#   Peserta['Harga Penawaran'] = Peserta['Harga Penawaran'].str.replace('Rp. ', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:19: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Peserta['Harga Penawaran'] = Peserta['Harga Penawaran'].str.replace('.', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:21: FutureWarning: The default value of regex will change from True to False in a future version.
#   Peserta['Harga Terkoreksi'] = Peserta['Harga Terkoreksi'].str.replace('Rp. ', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Peserta['Harga Terkoreksi'] = Peserta['Harga Terkoreksi'].str.replace('.', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:5: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str(link)).click()
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str('//*[@id="main"]/ul/li[2]/a')).click()
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
#   Peserta['Harga Penawaran'] = Peserta['Harga Penawaran'].str.replace('Rp. ', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:19: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Peserta['Harga Penawaran'] = Peserta['Harga Penawaran'].str.replace('.', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:21: FutureWarning: The default value of regex will change from True to False in a future version.
#   Peserta['Harga Terkoreksi'] = Peserta['Harga Terkoreksi'].str.replace('Rp. ', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Peserta['Harga Terkoreksi'] = Peserta['Harga Terkoreksi'].str.replace('.', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:5: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str(link)).click()
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str('//*[@id="main"]/ul/li[2]/a')).click()
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
#   Peserta['Harga Penawaran'] = Peserta['Harga Penawaran'].str.replace('Rp. ', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:19: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Peserta['Harga Penawaran'] = Peserta['Harga Penawaran'].str.replace('.', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:21: FutureWarning: The default value of regex will change from True to False in a future version.
#   Peserta['Harga Terkoreksi'] = Peserta['Harga Terkoreksi'].str.replace('Rp. ', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Peserta['Harga Terkoreksi'] = Peserta['Harga Terkoreksi'].str.replace('.', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:5: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str(link)).click()
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str('//*[@id="main"]/ul/li[2]/a')).click()
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
#   Peserta['Harga Penawaran'] = Peserta['Harga Penawaran'].str.replace('Rp. ', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:19: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Peserta['Harga Penawaran'] = Peserta['Harga Penawaran'].str.replace('.', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:21: FutureWarning: The default value of regex will change from True to False in a future version.
#   Peserta['Harga Terkoreksi'] = Peserta['Harga Terkoreksi'].str.replace('Rp. ', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Peserta['Harga Terkoreksi'] = Peserta['Harga Terkoreksi'].str.replace('.', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:5: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str(link)).click()
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str('//*[@id="main"]/ul/li[2]/a')).click()
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
#   Peserta['Harga Penawaran'] = Peserta['Harga Penawaran'].str.replace('Rp. ', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:19: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Peserta['Harga Penawaran'] = Peserta['Harga Penawaran'].str.replace('.', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:21: FutureWarning: The default value of regex will change from True to False in a future version.
#   Peserta['Harga Terkoreksi'] = Peserta['Harga Terkoreksi'].str.replace('Rp. ', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Peserta['Harga Terkoreksi'] = Peserta['Harga Terkoreksi'].str.replace('.', '')
#   0%|          | 1/436 [00:21<2:35:56, 21.51s/it]C:\Users\madej\AppData\Local\Temp\ipykernel_9056\2318968024.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   halamanutama_all = halamanutama_all.append(halamanutama, ignore_index=True)
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\2318968024.py:6: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str('//*[@id="tbllelang_next"]/a')).click()
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:5: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str(link)).click()
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str('//*[@id="main"]/ul/li[2]/a')).click()
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
#   Peserta['Harga Penawaran'] = Peserta['Harga Penawaran'].str.replace('Rp. ', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:19: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Peserta['Harga Penawaran'] = Peserta['Harga Penawaran'].str.replace('.', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:21: FutureWarning: The default value of regex will change from True to False in a future version.
#   Peserta['Harga Terkoreksi'] = Peserta['Harga Terkoreksi'].str.replace('Rp. ', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Peserta['Harga Terkoreksi'] = Peserta['Harga Terkoreksi'].str.replace('.', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:5: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str(link)).click()
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str('//*[@id="main"]/ul/li[2]/a')).click()
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
#   Peserta['Harga Penawaran'] = Peserta['Harga Penawaran'].str.replace('Rp. ', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:19: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Peserta['Harga Penawaran'] = Peserta['Harga Penawaran'].str.replace('.', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:21: FutureWarning: The default value of regex will change from True to False in a future version.
#   Peserta['Harga Terkoreksi'] = Peserta['Harga Terkoreksi'].str.replace('Rp. ', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Peserta['Harga Terkoreksi'] = Peserta['Harga Terkoreksi'].str.replace('.', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:5: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str(link)).click()
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str('//*[@id="main"]/ul/li[2]/a')).click()
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
#   Peserta['Harga Penawaran'] = Peserta['Harga Penawaran'].str.replace('Rp. ', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:19: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Peserta['Harga Penawaran'] = Peserta['Harga Penawaran'].str.replace('.', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:21: FutureWarning: The default value of regex will change from True to False in a future version.
#   Peserta['Harga Terkoreksi'] = Peserta['Harga Terkoreksi'].str.replace('Rp. ', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Peserta['Harga Terkoreksi'] = Peserta['Harga Terkoreksi'].str.replace('.', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:5: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str(link)).click()
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str('//*[@id="main"]/ul/li[2]/a')).click()
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
#   Peserta['Harga Penawaran'] = Peserta['Harga Penawaran'].str.replace('Rp. ', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:19: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Peserta['Harga Penawaran'] = Peserta['Harga Penawaran'].str.replace('.', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:21: FutureWarning: The default value of regex will change from True to False in a future version.
#   Peserta['Harga Terkoreksi'] = Peserta['Harga Terkoreksi'].str.replace('Rp. ', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Peserta['Harga Terkoreksi'] = Peserta['Harga Terkoreksi'].str.replace('.', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:5: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str(link)).click()
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str('//*[@id="main"]/ul/li[2]/a')).click()
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
#   Peserta['Harga Penawaran'] = Peserta['Harga Penawaran'].str.replace('Rp. ', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:19: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Peserta['Harga Penawaran'] = Peserta['Harga Penawaran'].str.replace('.', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:21: FutureWarning: The default value of regex will change from True to False in a future version.
#   Peserta['Harga Terkoreksi'] = Peserta['Harga Terkoreksi'].str.replace('Rp. ', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Peserta['Harga Terkoreksi'] = Peserta['Harga Terkoreksi'].str.replace('.', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:5: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str(link)).click()
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str('//*[@id="main"]/ul/li[2]/a')).click()
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# ...
#   Peserta['Harga Terkoreksi'] = Peserta['Harga Terkoreksi'].str.replace('Rp. ', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Peserta['Harga Terkoreksi'] = Peserta['Harga Terkoreksi'].str.replace('.', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:5: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str(link)).click()
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str('//*[@id="main"]/ul/li[2]/a')).click()
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
#   Peserta['Harga Penawaran'] = Peserta['Harga Penawaran'].str.replace('Rp. ', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:19: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Peserta['Harga Penawaran'] = Peserta['Harga Penawaran'].str.replace('.', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:21: FutureWarning: The default value of regex will change from True to False in a future version.
#   Peserta['Harga Terkoreksi'] = Peserta['Harga Terkoreksi'].str.replace('Rp. ', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Peserta['Harga Terkoreksi'] = Peserta['Harga Terkoreksi'].str.replace('.', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:5: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str(link)).click()
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str('//*[@id="main"]/ul/li[2]/a')).click()
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
#   Peserta['Harga Penawaran'] = Peserta['Harga Penawaran'].str.replace('Rp. ', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:19: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Peserta['Harga Penawaran'] = Peserta['Harga Penawaran'].str.replace('.', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:21: FutureWarning: The default value of regex will change from True to False in a future version.
#   Peserta['Harga Terkoreksi'] = Peserta['Harga Terkoreksi'].str.replace('Rp. ', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Peserta['Harga Terkoreksi'] = Peserta['Harga Terkoreksi'].str.replace('.', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:5: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str(link)).click()
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str('//*[@id="main"]/ul/li[2]/a')).click()
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
#   Peserta['Harga Penawaran'] = Peserta['Harga Penawaran'].str.replace('Rp. ', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:19: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Peserta['Harga Penawaran'] = Peserta['Harga Penawaran'].str.replace('.', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:21: FutureWarning: The default value of regex will change from True to False in a future version.
#   Peserta['Harga Terkoreksi'] = Peserta['Harga Terkoreksi'].str.replace('Rp. ', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Peserta['Harga Terkoreksi'] = Peserta['Harga Terkoreksi'].str.replace('.', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:5: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str(link)).click()
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str('//*[@id="main"]/ul/li[2]/a')).click()
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
#   Peserta['Harga Penawaran'] = Peserta['Harga Penawaran'].str.replace('Rp. ', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:19: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Peserta['Harga Penawaran'] = Peserta['Harga Penawaran'].str.replace('.', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:21: FutureWarning: The default value of regex will change from True to False in a future version.
#   Peserta['Harga Terkoreksi'] = Peserta['Harga Terkoreksi'].str.replace('Rp. ', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Peserta['Harga Terkoreksi'] = Peserta['Harga Terkoreksi'].str.replace('.', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:5: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str(link)).click()
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str('//*[@id="main"]/ul/li[2]/a')).click()
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
#   Peserta['Harga Penawaran'] = Peserta['Harga Penawaran'].str.replace('Rp. ', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:19: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Peserta['Harga Penawaran'] = Peserta['Harga Penawaran'].str.replace('.', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:21: FutureWarning: The default value of regex will change from True to False in a future version.
#   Peserta['Harga Terkoreksi'] = Peserta['Harga Terkoreksi'].str.replace('Rp. ', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Peserta['Harga Terkoreksi'] = Peserta['Harga Terkoreksi'].str.replace('.', '')
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:5: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str(link)).click()
# Erorr15
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str('//*[@id="main"]/ul/li[2]/a')).click()
# Erorr16
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:5: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str(link)).click()
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str('//*[@id="main"]/ul/li[2]/a')).click()
# Erorr17
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:5: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str(link)).click()
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str('//*[@id="main"]/ul/li[2]/a')).click()
# Erorr18
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:5: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str(link)).click()
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str('//*[@id="main"]/ul/li[2]/a')).click()
# Erorr19
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:5: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str(link)).click()
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str('//*[@id="main"]/ul/li[2]/a')).click()
# Erorr20
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:5: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str(link)).click()
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str('//*[@id="main"]/ul/li[2]/a')).click()
# Erorr21
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:5: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str(link)).click()
# Erorr22
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str('//*[@id="main"]/ul/li[2]/a')).click()
# Erorr23
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:5: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str(link)).click()
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\1027270064.py:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str('//*[@id="main"]/ul/li[2]/a')).click()
#   4%|▎         | 16/436 [05:08<2:18:20, 19.76s/it]
# Erorr24
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\2318968024.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   halamanutama_all = halamanutama_all.append(halamanutama, ignore_index=True)
# C:\Users\madej\AppData\Local\Temp\ipykernel_9056\2318968024.py:6: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(str('//*[@id="tbllelang_next"]/a')).click()
#   4%|▎         | 16/436 [05:13<2:16:58, 19.57s/it]
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9056\2318968024.py in <module>
#       4     halamanutama = pd.DataFrame(pd.read_html(driver.page_source)[1])
#       5     halamanutama_all = halamanutama_all.append(halamanutama, ignore_index=True)
# ----> 6     driver.find_element_by_xpath(str('//*[@id="tbllelang_next"]/a')).click()
#       7     for ii in range(1,len(pd.read_html(driver.page_source)[1])):
#       8         try:
#
# c:\Users\madej\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     512             stacklevel=2,
#     513         )
# --> 514         return self.find_element(by=By.XPATH, value=xpath)
#     515
#     516     def find_elements_by_xpath(self, xpath) -> WebElement:
#
# c:\Users\madej\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#    1236             value = '[name="%s"]' % value
#    1237
# -> 1238         return self.execute(Command.FIND_ELEMENT, {
#    1239             'using': by,
#    1240             'value': value})['value']
#
# c:\Users\madej\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     416         response = self.command_executor.execute(driver_command, params)
#     417         if response:
# --> 418             self.error_handler.check_response(response)
#     419             response['value'] = self._unwrap_value(
#     420                 response.get('value', None))
#
# c:\Users\madej\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     241                 alert_text = value['alert'].get('text')
#     242             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 243         raise exception_class(message, screen, stacktrace)
#     244
#     245     def _value_or_default(self, obj: Mapping[_KT, _VT], key: _KT, default: _VT) -> _VT:
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="tbllelang_next"]/a"}
#   (Session info: chrome=107.0.5304.107)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x002BACD3+2075859]
# 	Ordinal0 [0x0024EE61+1633889]
# 	Ordinal0 [0x0014B7BD+571325]
# 	Ordinal0 [0x0017AC2F+764975]
# 	Ordinal0 [0x0017AE1B+765467]
# 	Ordinal0 [0x001AD0F2+970994]
# 	Ordinal0 [0x00197364+881508]
# 	Ordinal0 [0x001AB56A+963946]
# 	Ordinal0 [0x00197136+880950]
# 	Ordinal0 [0x0016FEFD+720637]
# 	Ordinal0 [0x00170F3F+724799]
# 	GetHandleVerifier [0x0056EED2+2769538]
# 	GetHandleVerifier [0x00560D95+2711877]
# 	GetHandleVerifier [0x0034A03A+521194]
# 	GetHandleVerifier [0x00348DA0+516432]
# 	Ordinal0 [0x0025682C+1665068]
# 	Ordinal0 [0x0025B128+1683752]
# 	Ordinal0 [0x0025B215+1683989]
# 	Ordinal0 [0x00266484+1729668]
# 	BaseThreadInitThunk [0x76206939+25]
# 	RtlGetFullPathName_UEx [0x775A8FD2+1218]
# 	RtlGetFullPathName_UEx [0x775A8F9D+1165]
# 	(No symbol) [0x00000000]

# %%
writer = pd.ExcelWriter("LPSE_POV_KALTIM/halamanutama_all"+'.xlsx', engine='xlsxwriter')
halamanutama_all.to_excel(writer, sheet_name='Pengumuman')
halamanutama_all.to_excel(writer, sheet_name='Peserta')
writer.save()
